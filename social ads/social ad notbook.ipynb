# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("social_Network_Ads.csv", sep = ',')

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#people thatdid not purchase
not_Purchased = data['Purchased']==0
Purchased,not_Purchased =data[~not_Purchased], data[not_Purchased]
Purchased.describe()
# Out:
#             User ID         Age  EstimatedSalary  Purchased
# count  1.430000e+02  143.000000       143.000000      143.0
# mean   1.569222e+07   46.391608     86272.727273        1.0
# std    7.112851e+04    8.612172     42064.200064        0.0
# min    1.556964e+07   27.000000     20000.000000        1.0
# 25%    1.563045e+07   39.500000     41000.000000        1.0
# 50%    1.569483e+07   47.000000     90000.000000        1.0
# 75%    1.574972e+07   53.000000    122500.000000        1.0
# max    1.581524e+07   60.000000    150000.000000        1.0

# %%
not_Purchased.describe()
# Out:
#             User ID         Age  EstimatedSalary  Purchased
# count  2.570000e+02  257.000000       257.000000      257.0
# mean   1.569116e+07   32.793774     60544.747082        0.0
# std    7.208696e+04    7.985844     24351.570102        0.0
# min    1.556669e+07   18.000000     15000.000000        0.0
# 25%    1.562451e+07   26.000000     44000.000000        0.0
# 50%    1.569326e+07   34.000000     61000.000000        0.0
# 75%    1.575387e+07   38.000000     77000.000000        0.0
# max    1.581482e+07   59.000000    141000.000000        0.0

# %%
data["Purchased"].value_counts().plot(kind="barh");

# %%
# what is the percentage of people that made a purchase
Purchase_counts = data["Purchased"].value_counts()
Percentage_Purchase = (Purchase_counts[1] / Purchase_counts.sum()) * 100
print(f'Percentage of people who made a Purchase: {Percentage_Purchase:.2f}%')
# Out:
# Percentage of people who made a Purchase: 35.75%

# %%
Purchase_counts = data["Purchased"].value_counts()
Percentage_Purchase = (Purchase_counts[0] / Purchase_counts.sum()) * 100
print(f'Percentage of people who made a Purchase: {Percentage_Purchase:.2f}%')
# Out:
# Percentage of people who made a Purchase: 64.25%

# %%
average_age_purchase = data[data['Purchased'] == 1]['Age'].mean()
average_salary_purchase = data[data['Purchased'] == 1]['EstimatedSalary'].mean()
average_age_no_purchase = data[data['Purchased'] == 0]['Age'].mean()
average_salary_no_purchase = data[data['Purchased'] == 0]['EstimatedSalary'].mean()
print('Average Age of Purchase:', average_age_purchase)
print('Average Estimated Salary of Purchase:', average_salary_purchase)
print('Average Age of No Purchase:', average_age_no_purchase)
print('Average Estimated Salary of No Purchase:', average_salary_no_purchase)
# Out:
# Average Age of Purchase: 46.39160839160839
# Average Estimated Salary of Purchase: 86272.72727272728
# Average Age of No Purchase: 32.793774319066145
# Average Estimated Salary of No Purchase: 60544.74708171206

# %%
data.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
sns.boxplot(x='Purchased', y='Age', data=data)
plt.title('Age vs. Purchase')
plt.show()

# %%
sns.boxplot(x='Purchased', y='EstimatedSalary', data=data)
plt.title('Estimated Salary vs. Purchase')
plt.show()

# %%
sns.kdeplot(data[data['Purchased'] == 1]['EstimatedSalary'], label='Purchased')
sns.kdeplot(data[data['Purchased'] == 0]['EstimatedSalary'], label='Not Purchased')
plt.title('Estimated Salary Distribution')
plt.xlabel('Estimated Salary')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
sns.boxplot(data=data[['Age', 'EstimatedSalary']])
plt.title('Boxplot of Age and Estimated Salary')
plt.show()
